# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pydataset import data
import statistics
import seaborn as sns
import env
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import scipy
import acquire
import prepare
import explore
from scipy import stats

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
import sklearn.linear_model
import sklearn.preprocessing
import warnings
warnings.filterwarnings("ignore")
# importing my personal wrangle module
import wrangle

# %%
mall_data = acquire.get_mall_data()
mall= mall_data.copy()
mall.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
cat_vars=['gender']
cont_vars=['age','annual_income','spending_score']

# %%
non_target_vars = ['age','annual_income','gender']

for var in non_target_vars:
    explore.plot_variable_pairs(var,'spending_score',mall)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-8-cced944d3acc> in <module>
#       2
#       3 for var in non_target_vars:
# ----> 4     explore.plot_variable_pairs(var,'spending_score',mall)
#
# ~/codeup-data-science/regression_exercises/explore.py in plot_variable_pairs(x, y, df)
#      43
#      44     '''
# ---> 45     sns.jointplot(x=x, y=y, data=df,  kind='reg', height=5)
#      46     plt.show()
#      47
#
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
explore.plot_categorical_and_continuous_vars(cat_vars,cont_vars,mall)
